# %%
import pandas as pd
import numpy
from sqlalchemy import create_engine

# %% [markdown]
# # Store CSV into DataFrame

# %%
csv_file = "Resources/Malaria_deaths_report_clean_up_csv.csv"
raw_malaria_df = pd.read_csv(csv_file)
raw_malaria_df.head(110)
# Out:
#              Countries   2000   2001    2002    2003    2004    2005    2006  \
# 0              Algeria      0      0       0       0       0       0       0
# 1               Angola  9,510  9,473  14,434  38,598  12,459  13,768  10,220
# 2                Benin      0      0       0       0       0       0   1,226
# 3             Botswana      0      0       0       0       0       0       0
# 4         Burkina Faso      0  4,233   4,032   4,860   4,205   5,224   8,083
# ..                 ...    ...    ...     ...     ...     ...     ...     ...
# 100        Philippines    536    439      71     162     167     145     124
# 101  Republic of Korea      0      0       0       0       0       0       0
# 102    Solomon Islands     38     55      61      71      51      38      12
# 103            Vanuatu      3      4      13      14       3       5       1
# 104           Viet Nam    142     91      50      50      34      18      41
#
# ...

# %%
## dir(raw_malaria_df)
raw_malaria_df.dtypes
# raw_malaria_df.mean(axis=1)
# Out:
# Countries    object
# 2000         object
# 2001         object
# 2002         object
# 2003         object
# 2004         object
# 2005         object
# 2006         object
# 2007         object
# 2008         object
# 2009         object
# 2010         object
# 2011         object
# 2012         object
# 2013         object
# 2014         object
# 2015         object
# 2016         object
# 2017         object
# 2018         object
# dtype: object

# %%
# raw_malaria_df1 = raw_malaria_df[raw_malaria_df.isna().any(axis=1)]
raw_malaria_df.isnull()
raw_malaria_df.fillna(0)

raw_malaria_df['2000']=raw_malaria_df['2000'].str.replace(',', '')
   
    
# df.to_csv(file_name, sep='\t', encoding='utf-8')
raw_malaria_df.to_csv("malaria_output", sep='\t', encoding='utf-8')
